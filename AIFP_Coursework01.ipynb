# %% [markdown]
# <a href="https://colab.research.google.com/github/Met37/AIFP/blob/main/AIFP_Coursework01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **up2293815**

# %% [markdown]
# # **Importing the Libraries and reading the dataset**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('heart_attack.csv')

# %% [markdown]
# # **Understanding Data**

# %%
df.shape
# Out:
# (129998, 16)

# %%
df.head()
# Out:
#    HeartDiseaseorAttack  HighBP  HighChol  CholCheck   BMI  Smoker  Stroke  \
# 0                     0       1         1          1  40.0       1       0
# 1                     0       0         0          0  25.0       1       0
# 2                     0       1         1          1  28.0       0       0
# 3                     0       1         0          1  27.0       0       0
# 4                     0       1         1          1  24.0       0       0
#
#    Diabetes  PhysActivity  HvyAlcoholConsump  MentHlth  PhysHlth  Sex  Age  \
# 0         0             0                  0        18        15    0    9
# 1         0             1                  0         0         0    0    7
# 2         0             0                  0        30        30    0    9
# 3         0             1                  0         0         0    0   11
# 4         0             1                  0         3         0    0   11
#
#    Education  Income
# 0          4       3
# ...

# %%
df.dtypes
# Out:
# HeartDiseaseorAttack      int64
# HighBP                    int64
# HighChol                  int64
# CholCheck                 int64
# BMI                     float64
# Smoker                    int64
# Stroke                    int64
# Diabetes                  int64
# PhysActivity              int64
# HvyAlcoholConsump         int64
# MentHlth                  int64
# PhysHlth                  int64
# Sex                       int64
# Age                       int64
# Education                 int64
# Income                    int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# HeartDiseaseorAttack     0
# HighBP                   0
# HighChol                 0
# CholCheck                0
# BMI                     10
# Smoker                   0
# Stroke                   0
# Diabetes                 0
# PhysActivity             0
# HvyAlcoholConsump        0
# MentHlth                 0
# PhysHlth                 0
# Sex                      0
# Age                      0
# Education                0
# Income                   0
# dtype: int64

# %%
df.shape
# Out:
# (129998, 16)

# %%
df.describe()
# Out:
#        HeartDiseaseorAttack         HighBP       HighChol      CholCheck  \
# count         129998.000000  129998.000000  129998.000000  129998.000000
# mean               0.093509       0.429614       0.426322       0.963315
# std                0.291146       0.495023       0.494544       0.187988
# min                0.000000       0.000000       0.000000       0.000000
# 25%                0.000000       0.000000       0.000000       1.000000
# 50%                0.000000       0.000000       0.000000       1.000000
# 75%                0.000000       1.000000       1.000000       1.000000
# max                1.000000       1.000000       1.000000       1.000000
#
#                  BMI         Smoker         Stroke       Diabetes  \
# count  129988.000000  129998.000000  129998.000000  129998.000000
# mean       28.435586       0.448030       0.041354       0.296689
# std         6.999582       0.497294       0.199110       0.697608
# ...

# %%
import seaborn as sns
sns.boxplot(df['BMI'])
plt.show()

# %% [markdown]
# # **Data Preparation**

# %%
df=df.dropna(subset=['BMI'])
df.dropna()
# Out:
#         HeartDiseaseorAttack  HighBP  HighChol  CholCheck   BMI  Smoker  \
# 0                          0       1         1          1  40.0       1
# 1                          0       0         0          0  25.0       1
# 2                          0       1         1          1  28.0       0
# 3                          0       1         0          1  27.0       0
# 4                          0       1         1          1  24.0       0
# ...                      ...     ...       ...        ...   ...     ...
# 129993                     0       1         1          1  25.0       1
# 129994                     0       0         0          1  27.0       0
# 129995                     0       0         0          1  29.0       0
# 129996                     0       0         0          0  21.0       0
# 129997                     0       0         0          1  21.0       1
#
#         Stroke  Diabetes  PhysActivity  HvyAlcoholConsump  MentHlth  PhysHlth  \
# ...

# %%
df.isnull().sum()
# Out:
# HeartDiseaseorAttack    0
# HighBP                  0
# HighChol                0
# CholCheck               0
# BMI                     0
# Smoker                  0
# Stroke                  0
# Diabetes                0
# PhysActivity            0
# HvyAlcoholConsump       0
# MentHlth                0
# PhysHlth                0
# Sex                     0
# Age                     0
# Education               0
# Income                  0
# dtype: int64

# %%
#pearsons correlation between numerical attributes
import seaborn as sns
df_corr=df.select_dtypes(include=['number'])
pearsoncorr=df_corr.corr(method='pearson')
plt.figure(figsize=(30,20))
sns.heatmap(pearsoncorr,
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=2)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (129988, 16)

# %%
df['HeartDiseaseorAttack'].value_counts()
# Out:
# HeartDiseaseorAttack
# 0    117833
# 1     12155
# Name: count, dtype: int64

# %% [markdown]
# # **Splitting dataset**

# %%
df.dtypes
# Out:
# HeartDiseaseorAttack      int64
# HighBP                    int64
# HighChol                  int64
# CholCheck                 int64
# BMI                     float64
# Smoker                    int64
# Stroke                    int64
# Diabetes                  int64
# PhysActivity              int64
# HvyAlcoholConsump         int64
# MentHlth                  int64
# PhysHlth                  int64
# Sex                       int64
# Age                       int64
# Education                 int64
# Income                    int64
# dtype: object

# %%
X = df.drop('HeartDiseaseorAttack', axis=1)

# %%
X.values
# Out:
# array([[ 1.,  1.,  1., ...,  9.,  4.,  3.],
#        [ 0.,  0.,  0., ...,  7.,  6.,  1.],
#        [ 1.,  1.,  1., ...,  9.,  4.,  8.],
#        ...,
#        [ 0.,  0.,  1., ...,  4.,  6.,  8.],
#        [ 0.,  0.,  0., ...,  4.,  6.,  8.],
#        [ 0.,  0.,  1., ..., 10.,  6.,  6.]])

# %%
y=df['HeartDiseaseorAttack']
print(y.dtypes)
y.values
# Out:
# int64
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y.value_counts()
# Out:
# HeartDiseaseorAttack
# 0    117833
# 1     12155
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
X_train=min_max_scaler.fit_transform(X_train)
X_test=min_max_scaler.transform(X_test)

# %% [markdown]
# # **KNN**

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
from sklearn.neighbors import KNeighborsClassifier
k=3
KNN = KNeighborsClassifier(n_neighbors =k)


KNN.fit(X_train, y_train)



yknnpredicted = KNN.predict(X_test)
cm=confusion_matrix(y_test,yknnpredicted)
print(cm)


import seaborn as sns
sns.heatmap(cm, annot=True)

print(classification_report(y_test, yknnpredicted))
print("Accuracy:", accuracy_score(y_test, yknnpredicted))
print("F1_score:",f1_score(y_test, yknnpredicted, average='weighted'))
F1_knn=f1_score(y_test, yknnpredicted, average='weighted')
# Out:
# [[22666   892]
#  [ 2032   408]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     23558
#            1       0.31      0.17      0.22      2440
#
#     accuracy                           0.89     25998
#    macro avg       0.62      0.56      0.58     25998
# weighted avg       0.86      0.89      0.87     25998
#
# Accuracy: 0.8875298099853834
# F1_score: 0.8717171294760983

# %% [markdown]
# # **SVM**

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import f1_score


svm = SVC(kernel='poly')
svm.fit(X_train, y_train)

ysvmpredicted=svm.predict(X_test)
cm=confusion_matrix(y_test,ysvmpredicted)
print(cm)

import seaborn as sns
sns.heatmap(cm, annot=True)

print(classification_report(y_test, ysvmpredicted))
print("Accuracy:", accuracy_score(y_test, ysvmpredicted))
print("F1_score:",f1_score(y_test, ysvmpredicted, average='weighted'))
F1_svm=f1_score(y_test, ysvmpredicted, average='weighted')
# Out:
# [[22828   730]
#  [ 2152   288]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     23558
#            1       0.28      0.12      0.17      2440
#
#     accuracy                           0.89     25998
#    macro avg       0.60      0.54      0.55     25998
# weighted avg       0.85      0.89      0.87     25998
#
# Accuracy: 0.8891453188706824
# F1_score: 0.8679763024940915

# %% [markdown]
# # **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)


yrfpredicted=rf.predict(X_test)
cm=confusion_matrix(y_test,yrfpredicted)
print(cm)


import seaborn as sns
sns.heatmap(cm, annot=True)


print(classification_report(y_test, yrfpredicted))
print("Accuracy:", accuracy_score(y_test, yrfpredicted))
print("F1_score:",f1_score(y_test, yrfpredicted, average='weighted'))
F1_rf=f1_score(y_test, yrfpredicted, average='weighted')
# Out:
# [[23278   280]
#  [ 2247   193]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     23558
#            1       0.41      0.08      0.13      2440
#
#     accuracy                           0.90     25998
#    macro avg       0.66      0.53      0.54     25998
# weighted avg       0.86      0.90      0.87     25998
#
# Accuracy: 0.9028002154011847
# F1_score: 0.8719308318192965

# %% [markdown]
# # **ANN**

# %%
import pandas as pd
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay, accuracy_score, classification_report, f1_score, recall_score, precision_score
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import Adam
import numpy as np

# %%
scaled = StandardScaler()
X= scaled.fit_transform(X_train)
X_test = scaled.transform(X_test)

# %%
classifier = Sequential()
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, activation = 'relu', input_dim = 15))
# Adding the second hidden layer
classifier.add(Dense(units = 6,  activation = 'relu'))
# Adding the output layer
classifier.add(Dense(units = 1,activation = 'sigmoid'))

# %%
# Compiling the ANN | means applying SGD on the whole ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, validation_split=0.1, epochs = 100)
# Predicting the Test set results
y_pred = classifier.predict(X_test)
print(y_pred.dtype)
y_pred=np.round(y_pred).astype(int)
print('Accuracy Score: {:.4f}'.format(accuracy_score(y_test, y_pred)))
print('f1-score  : {:.4f}'.format(f1_score(y_pred, y_test)))
print('Precision : {:.4f}'.format(precision_score(y_pred, y_test)))
print('Recall    : {:.4f}'.format(recall_score(y_pred, y_test)))
print(classification_report(y_test, y_pred))
# Out:
# Epoch 1/100
# 2925/2925 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8125 - loss: 0.4034 - val_accuracy: 0.9110 - val_loss: 0.2477
# Epoch 2/100
# 2925/2925 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9062 - loss: 0.2560 - val_accuracy: 0.9110 - val_loss: 0.2428
# Epoch 3/100
# 2925/2925 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9084 - loss: 0.2487 - val_accuracy: 0.9110 - val_loss: 0.2413
# Epoch 4/100
# 2925/2925 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9062 - loss: 0.2478 - val_accuracy: 0.9105 - val_loss: 0.2415
# Epoch 5/100
# 2925/2925 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9088 - loss: 0.2440 - val_accuracy: 0.9109 - val_loss: 0.2404
# Epoch 6/100
# 2925/2925 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9073 - loss: 0.2463 - val_accuracy: 0.9105 - val_loss: 0.2394
# Epoch 7/100
# 2925/2925 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9091 - loss: 0.2418 - val_accuracy: 0.9112 - val_loss: 0.2413
# Epoch 8/100
# ...

# %%
cf_matrix = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(cf_matrix).plot()

# %%
F1_ann=f1_score(y_test, y_pred, average='weighted')
print("F1_score:",f1_score(y_test, y_pred, average='weighted'))
# Out:
# F1_score: 0.6806151911277524

# %% [markdown]
# # **XGB**

# %%
pip install xgboost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, classification_report
import seaborn as sns

# Initialize the XGBoost classifier
XGB = XGBClassifier()

# Fit the classifier on the training data
XGB.fit(X_train, y_train)

# Make predictions on the test set
yXGBpredicted = XGB.predict(X_test)

# Confusion matrix
cm = confusion_matrix(y_test, yXGBpredicted)
print(cm)

# Heatmap for the confusion matrix
sns.heatmap(cm, annot=True, fmt='d')

# Classification report
print(classification_report(y_test, yXGBpredicted))

# Accuracy and F1 score
print("Accuracy:", accuracy_score(y_test, yXGBpredicted))
print("F1_score:", f1_score(y_test, yXGBpredicted, average='weighted'))

# Store the F1 score in a variable
F1_XGB = f1_score(y_test, yXGBpredicted, average='weighted')
# Out:
# [[21992  1566]
#  [ 1890   550]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93     23558
#            1       0.26      0.23      0.24      2440
#
#     accuracy                           0.87     25998
#    macro avg       0.59      0.58      0.58     25998
# weighted avg       0.86      0.87      0.86     25998
#
# Accuracy: 0.8670666974382645
# F1_score: 0.8627938665891159

# %% [markdown]
# # **Comparing Models**

# %%
models = ['KNN', 'SVM','Random Forest','ANN','XGBoost']
F1_score = [F1_knn, F1_svm, F1_rf, F1_ann,F1_XGB]
compare_models = pd.DataFrame({ 'Algorithms': models, 'F1 Score':
F1_score })
compare_models.sort_values(by = 'F1 Score', ascending = False)


# Sort the DataFrame by F1 Score in descending order
compare_models = compare_models.sort_values(by='F1 Score', ascending=False)

# Plot the sorted DataFrame
plt.figure(figsize=(8, 8))
sns.barplot(x='F1 Score', y='Algorithms', data=compare_models)
plt.show()

# %% [markdown]
# # **Improving Score**

# %%
#identify a better value of k
from sklearn import metrics

k_range = range(3,13)

scores=[]

for k in k_range:
  kNN=KNeighborsClassifier(n_neighbors=k)
  kNN.fit(X_train, y_train)
  y_pred = kNN.predict(X_test)
  scores.append(metrics.accuracy_score(y_test, y_pred))
print(scores)
# Out:
# [0.8883375644280329, 0.9005692745595815, 0.8964151088545272, 0.901530886991307, 0.8983767982152473, 0.9019924609585352, 0.9005308100623125, 0.9025694284175706, 0.9013770290022309, 0.9028002154011847]

# %%
k=6
KNN = KNeighborsClassifier(n_neighbors =k)


KNN.fit(X_train, y_train)



yknnpredicted = KNN.predict(X_test)
cm=confusion_matrix(y_test,yknnpredicted)
print(cm)


import seaborn as sns
sns.heatmap(cm, annot=True)

print(classification_report(y_test, yknnpredicted))
print("Accuracy:", accuracy_score(y_test, yknnpredicted))
print("F1_score:",f1_score(y_test, yknnpredicted, average='weighted'))
F1_knn=f1_score(y_test, yknnpredicted, average='weighted')
# Out:
# [[23228   330]
#  [ 2230   210]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     23558
#            1       0.39      0.09      0.14      2440
#
#     accuracy                           0.90     25998
#    macro avg       0.65      0.54      0.54     25998
# weighted avg       0.86      0.90      0.87     25998
#
# Accuracy: 0.901530886991307
# F1_score: 0.8720481986776103

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
import numpy as np


k_range = range(3, 13)

cv_f1_scores = []
for k in k_range:

    KNN = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(KNN, X_train, y_train, cv=10, scoring='f1_weighted')
    cv_f1_scores.append(scores.mean())

best_k = k_range[np.argmax(cv_f1_scores)]
print("Best k:", best_k)
print("Best Cross-Validated F1 Score:", max(cv_f1_scores))
# Out:
# Best k: 7
# Best Cross-Validated F1 Score: 0.8767985834132312

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
best_knn = KNeighborsClassifier(n_neighbors=best_k)

best_knn.fit(X_train, y_train)
y_pred = best_knn.predict(X_test)

print("Confusion Matrix:")
cm = confusion_matrix(y_test, y_pred)
print(cm)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1_score:",f1_score(y_test, y_pred, average='weighted'))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title(f"Confusion Matrix for KNN with k={best_k}")
plt.show()
# Out:
# Confusion Matrix:
# [[23133   425]
#  [ 2154   286]]
# Accuracy: 0.9008000615431956
# F1_score: 0.8753395537822309
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.95     23558
#            1       0.40      0.12      0.18      2440
#
#     accuracy                           0.90     25998
#    macro avg       0.66      0.55      0.56     25998
# weighted avg       0.87      0.90      0.88     25998
